# %%
import pandas as pd


df = pd.read_excel(r"C:\Users\Gustavo Castro\Desktop\excel\vendas.xlsx")
display(str(df["Marca_Produto"].unique()))
# Out:
# array(['DELL', 'SAMSUNG', 'LOGITECH', 'ALTURA', 'SONY', 'JBL', 'AKG',
#        'BLUE'], dtype=object)
