# %%
import pandas as pd

df = pd.read_excel("categorias.xlsx")
df2 = pd.read_excel("produtos.xlsx")

display(df2[df2["Nome_Produto"].str.contains("Monitor", case=False, na=False)])
# Out:
#    ID_Produto                     Nome_Produto  ID_Categoria Marca_Produto  \
# 0           1  Monitor LED 19,5'' Full HD HDMI             1          DELL
# 1           2    Monitor Curvo 24'' 144Hz HDMI             1       SAMSUNG
#
#        Num_Serie  Preco_Unit  Custo_Unit
# 0  MNT-DL-831923        2300       966.0
# 1  MNT-SS-001939        2800       980.0
